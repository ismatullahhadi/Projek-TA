# %% [markdown]
# https://www.youtube.com/watch?v=QvcHrwXS4_U

# %%
# Support for maths
import numpy as np
# Plotting tools
from matplotlib import pyplot as plt
# we use the following for plotting figures in jupyter
# %matplotlib inline
# Importing data library
import pandas as pd

#Scikit learn GPR
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C, RationalQuadratic as RC, WhiteKernel, ExpSineSquared as Exp, DotProduct as Linear

np.random.seed(1)

# %%
# Pembacaan File Data Polusi Udara ISPU Excel
DKI1 = pd.read_excel("./Data/Normalization/DATA ISPU - Normalization.xlsx", sheet_name="DKI1")
DKI2 = pd.read_excel("./Data/Normalization/DATA ISPU - Normalization.xlsx", sheet_name="DKI2")
DKI3 = pd.read_excel("./Data/Normalization/DATA ISPU - Normalization.xlsx", sheet_name="DKI3")
DKI4 = pd.read_excel("./Data/Normalization/DATA ISPU - Normalization.xlsx", sheet_name="DKI4")
DKI5 = pd.read_excel("./Data/Normalization/DATA ISPU - Normalization.xlsx", sheet_name="DKI5")

# %%
# Menampilkan Data
DKI1
# Out:
#         Tanggal             Wilayah      PM10       SO2        CO        O3  \
# 0    2017-01-01  DKI1 (Bunderan HI)  0.719512  0.314286  0.458333  0.092308
# 1    2017-01-02  DKI1 (Bunderan HI)  0.146341  0.295238  0.270833  0.082051
# 2    2017-01-03  DKI1 (Bunderan HI)  0.170732  0.295238  0.291667  0.087179
# 3    2017-01-04  DKI1 (Bunderan HI)  0.243902  0.295238  0.395833  0.087179
# 4    2017-01-05  DKI1 (Bunderan HI)  0.304878  0.295238  0.458333  0.056410
# ...         ...                 ...       ...       ...       ...       ...
# 1760 2021-10-27  DKI1 (Bunderan HI)  0.621951  0.266667  0.250000  0.097436
# 1761 2021-10-28  DKI1 (Bunderan HI)  0.573171  0.257143  0.270833  0.097436
# 1762 2021-10-29  DKI1 (Bunderan HI)  0.560976  0.285714  0.333333  0.076923
# 1763 2021-10-30  DKI1 (Bunderan HI)  0.536585  0.285714  0.187500  0.112821
# 1764 2021-10-31  DKI1 (Bunderan HI)  0.597561  0.247619  0.166667  0.148718
#
#            NO2       Max Critical Kategori
# ...

# %% [markdown]
# Train Test Data

# %%
X = np.array(list(range(1,178)))
# X = np.array(DKI1['Tanggal'])
X = X.reshape(-1,1)
y = np.asarray(DKI1.head(177)['PM10'])
y = y.reshape(-1,1)

# %%
x = np.atleast_2d(np.linspace(1, 177, 10739))

# %% [markdown]
# Instantiate a Gaussian Process Model

# %%
kernel = C()*Exp(length_scale=24, periodicity=1)

gp = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=4)

# Fit to data using Maximum Likelihood Estimation of the Parameters
gp.fit(X, y)

# Make the predictions on the meshed x axis (ask for MSE as well)
y_pred, sigma = gp.predict(x, return_std=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7972/3248036206.py in <module>
#       7
#       8 # Make the predictions on the meshed x axis (ask for MSE as well)
# ----> 9 y_pred, sigma = gp.predict(x, return_std=True)
#
# ~\anaconda3\lib\site-packages\sklearn\gaussian_process\_gpr.py in predict(self, X, return_std, return_cov)
#     335                 return y_mean
#     336         else:  # Predict based on GP posterior
# --> 337             K_trans = self.kernel_(X, self.X_train_)
#     338             y_mean = K_trans.dot(self.alpha_)  # Line 4 (y_mean = f_star)
#     339             y_mean = self._y_train_mean + y_mean  # undo normal.
#
# ~\anaconda3\lib\site-packages\sklearn\gaussian_process\kernels.py in __call__(self, X, Y, eval_gradient)
#     816                                        K2_gradient * K1[:, :, np.newaxis]))
# ...

# %% [markdown]
# Plotting

# %%
# Plot figure
plt.figure(num=1, figsize=(11,0,8), dpi=300, facecolor='w', edgecolor='k')

plt.plot(X, y[:,0], 'r.', markersize=5, label=u'Oservation')
plt.plot(x, y_pred[:,0], 'b-', linewidth=1, label=u'Prediction')
plt.fill_between(x[:,0], y_pred[:,0] - 1.96*sigma, y_pred[:,0] + 1.96*sigma, alpha = 0.2, color='k', label=u'95 % confidence interval')
plt.xlabel('(a)')
plt.legend(loc='upper right', fontsize=10)
plt.ylim(-750, 1750)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7972/1962848799.py in <module>
#       1 # Plot figure
# ----> 2 plt.figure(num=1, figsize=(11,0,8), dpi=300, facecolor='w', edgecolor='k')
#       3
#       4 plt.plot(X, y[:,0], 'r.', markersize=5, label=u'Oservation')
#       5 plt.plot(x, y_pred[:,0], 'b-', linewidth=1, label=u'Prediction')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     685             dpi = 72
#     686
# --> 687         figManager = new_figure_manager(num, figsize=figsize,
#     688                                         dpi=dpi,
#     689                                         facecolor=facecolor,
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in new_figure_manager(*args, **kwargs)
# ...
